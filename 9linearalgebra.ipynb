# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorOlszewski2000/data-science/blob/main/9linearalgebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
v1 = np.array([-1,4])
v1
# Out:
# array([-1,  4])

# %%
np.linalg.norm(v1)
# Out:
# 4.123105625617661

# %% [markdown]
# Norma przestrzeni R^n

# %%
v2 = np.array([-10, 10, 13])
np.linalg.norm(v2)
# Out:
# 19.209372712298546

# %% [markdown]
# Odległość dwóch punktów na płaszczyźnie

# %%
p = np.array([3, 0])
q = np.array([0, 4])

np.linalg.norm(p - q)
# Out:
# 5.0

# %% [markdown]
# Odległość dwóch punktów w przestrzeni R^n

# %%
p = np.array([3, 0, 1])
q = np.array([0, 4, 2])

np.linalg.norm(p-q)
# Out:
# 5.0990195135927845
