# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorOlszewski2000/data-science/blob/main/6basicfunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
np.sqrt(9)
# Out:
# 3.0

# %%
np.all([2, 3, 1])
# Out:
# True

# %%
np.any([1, 2, 1])
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
A = np.random.randn(5)
A
# Out:
# array([-2.32721766,  1.40997473, -1.21887623,  0.00394272,  1.34462177])

# %%
np.argmax(A)
# Out:
# 1

# %%
A[np.argmax(A)]
# Out:
# 1.4099747326691585

# %%
A[np.argmin(A)]
# Out:
# -2.327217656681872

# %%
np.argsort(A)
# Out:
# array([0, 2, 3, 4, 1])

# %%
np.max(A)
# Out:
# 1.4099747326691585

# %%
np.mean(A)
# Out:
# -0.15751093199348115

# %%
np.median(A)
# Out:
# 0.00394272106391639

# %%
np.std(A)
# Out:
# 1.454208019295696
