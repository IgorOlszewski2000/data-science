# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorOlszewski2000/data-science/blob/main/10matrixmultiplication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
X = np.array([[5,3 ],[3, 9]])
Y = np.array([[1], [-1]])
print(X, '\n')
print(Y)
# Out:
# [[5 3]
#  [3 9]]
#
# [[ 1]
#  [-1]]

# %%
Z = np.dot(X, Y)
Z
# Out:
# array([[ 2],
#        [-6]])

# %%
Z.shape
# Out:
# (2, 1)

# %%
X = np.array([[2, -1 ,3],
              [3, 1, 0]])
Y = np.array([[2, 1, -1],
             [0, -1, 2],
             [3, 2, 0]])
print(X, '\n')
print(Y)

np.dot(X,Y)

# macierz tyle ile będzie wierszy w pierwszej macierzy i kolumn w drugiej macierzy ( taki będzie miała wymiar)
# Out:
# [[ 2 -1  3]
#  [ 3  1  0]]
#
# [[ 2  1 -1]
#  [ 0 -1  2]
#  [ 3  2  0]]
# array([[13,  9, -4],
#        [ 6,  2, -1]])
