# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorOlszewski2000/data-science/blob/main/2datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
A = np.array([1,2,3])
A.dtype
# Out:
# dtype('int64')

# %%
A = np.array([1,2,3], dtype="float")
A.dtype
# Out:
# dtype('float64')

# %%
A = np.array([1,2,3], dtype="complex")
A.dtype
# Out:
# dtype('complex128')

# %%
A = np.array([1.0,2.3,3.3], dtype="int")
A.dtype
# Out:
# dtype('int64')

# %%
A
# Out:
# array([1, 2, 3])

# %%
A = np.array([True,False])
A.dtype
# Out:
# dtype('bool')
