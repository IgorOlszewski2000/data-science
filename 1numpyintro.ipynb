# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorOlszewski2000/data-science/blob/main/1numpyintro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.__version__
# Out:
# '1.19.5'

# %%
print(dir(np))

# %%
help(np.array)

# %%
x = np.array([1, 3])
x
# Out:
# array([1, 3])

# %%
print(x)
type(x)
# Out:
# [1 3]
# numpy.ndarray

# %%
x.ndim # wymiar naszej tablicy
# Out:
# 2

# %%
x.shape #kształt
x.size #rozmiar
x.dtype #typ danych
# Out:
# dtype('int64')

# %%
x = np.array([1.3, 2.3, 1.4])
print(x)
# Out:
# [1.3 2.3 1.4]

# %%
x.dtype
# Out:
# dtype('float64')

# %%
x = np.array([[1, 2],[-3,1]])
x
# Out:
# array([[ 1,  2],
#        [-3,  1]])

# %%
x.ndim
# Out:
# 2

# %%
x = np.array([[1,2,4],[4,2,1]])
print(x)
# Out:
# [[1 2 4]
#  [4 2 1]]

# %%
x.shape
# Out:
# (2, 3)

# %%
x = np.array(
    [[[4, 3, 1],
      [3, 1, 2]],
     
     [[4, 1, 3],
      [4, 2, 1]]]
    )
x
# Out:
# array([[[4, 3, 1],
#         [3, 1, 2]],
#
#        [[4, 1, 3],
#         [4, 2, 1]]])

# %%
x.ndim
# Out:
# 3
